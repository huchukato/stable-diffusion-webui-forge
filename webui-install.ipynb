# %% [markdown]
# # Installation (run just the first time)
# Clone the repo and get the requirements to run 'Forge Web UI'

# %%
# Clone the repo
# !git clone https://github.com/huchukato/stable-diffusion-webui-forge.git

# %%
# Install requirements
# %cd stable-diffusion-webui-forge/
# %pip install --upgrade pip
# %pip install pickleshare
# %pip install -r requirements_versions.txt
# Out:
# /teamspace/studios/this_studio/stable-diffusion-webui-forge
# ...
#   Using cached pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-24.3.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached GitPython-3.1.32-py3-none-any.whl.metadata (10.0 kB)
# ...
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# ...
# Using cached GitPython-3.1.32-py3-none-any.whl (188 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.17
#     Uninstalling pydantic-1.10.17:
#       Successfully uninstalled pydantic-1.10.17
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.43
# ...

# %%
#Download the model
# %cd /teamspace/studios/this_studio/stable-diffusion-webui-forge/models/Stable-diffusion
# !wget https://huggingface.co/lllyasviel/flux1-dev-bnb-nf4/resolve/main/flux1-dev-bnb-nf4-v2.safetensors

# %% [markdown]
# # Run Forge UI
# After the first installation, just run the UI with the 'API' on port '7860' enabled and enjoy

# %%
# !python /teamspace/studios/this_studio/stable-diffusion-webui-forge/webui.py
# Out:
# Total VRAM 22700 MB, total RAM 61912 MB
# pytorch version: 2.5.1+cu124
# xformers version: 0.0.28.post3
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 NVIDIA L4 : native
# VAE dtype preferences: [torch.bfloat16, torch.float32] -> torch.bfloat16
# CUDA Using Stream: False
# 2024-11-19 02:55:19.397335: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731984919.460633    3635 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731984919.481335    3635 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Extra Models
# If you wanna try also SD3.5

# %%
# Download SD 3-5 Fusion fp16
# %cd /teamspace/studios/this_studio/stable-diffusion-webui-forge/models/Stable-diffusion
# !wget https://huggingface.co/huchukato/sd35-fusion-merge-fp16/resolve/main/sd35FusionMergefp16_v1.safetensors
